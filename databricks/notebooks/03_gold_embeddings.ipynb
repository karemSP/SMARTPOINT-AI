# %%
from pyspark.sql.types import *
from datetime import datetime

# %%
schema_bronz = StructType(
    [
        StructField("cv_id",StringType(),True),
        StructField("embedding",ArrayType(DoubleType()),True),
        StructField("embedding_model",StringType(),True),
        StructField("skills_normalized",StringType(),True),
        StructField("seniority",ArrayType(StringType()),True),
        StructField("industries",ArrayType(StringType()),True),
        StructField("cv_text_clean",StringType(),True),
        StructField("quality_score",StringType(),True),
        StructField("enriched_at",StringType(),True)
        
    ]
)
